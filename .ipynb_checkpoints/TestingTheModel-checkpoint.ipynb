# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-f40c52baac20> in <module>()
# ----> 1 get_ipython().magic('matplotlib inline')
#       2
#       3 import matplotlib.pyplot as plt
#       4 import numpy as np
#
# ~/miniconda3/envs/busca3/lib/python3.6/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2144         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2145         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2146         return self.run_line_magic(magic_name, magic_arg_s)
#    2147
#    2148     #-------------------------------------------------------------------------
#
# ~/miniconda3/envs/busca3/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2065                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
# ...

# %%
from gb import GrangerBusca

# %%
eps = 0.02
timestamps = [
    np.arange(100),
    np.arange(100) + eps,
    np.arange(200, 300),
    np.arange(200, 300) + eps,
]

# %%
granger_model = GrangerBusca(alpha_p=1, mu_p=450/100, rate_p=1, timestamps=timestamps)
# Out:
# ---------------------------------------------------------------------------
# MissingInputError                         Traceback (most recent call last)
# <ipython-input-4-232d5d6c1c78> in <module>()
# ----> 1 granger_model = GrangerBusca(alpha_p=1, mu_p=450/100, rate_p=1, timestamps=timestamps)
#
# /Users/flaviovdf/workspace/gb/gb.py in __init__(self, timestamps, rate_p, mu_p, alpha_p)
#      80         self.alpha_p = alpha_p
#      81         self.previous = previous
# ---> 82         self.model = self._build_model()
#      83
#      84     def _build_model(self):
#
# /Users/flaviovdf/workspace/gb/gb.py in _build_model(self)
#     108                               betas=beta_dists, alphas=alpha_dists,
#     109                               timestamps=stamps[i], previous=self.previous[i],
# --> 110                               observed=stamps[i])
#     111                 busca_dists.append(busca)
#     112
#
# ...

# %%
granger_model.fit()
